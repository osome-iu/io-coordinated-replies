# %% [markdown]
# #### **This notebook checks the activity difference**

# %%
import pandas as pd
import numpy as np

import importlib

#### packages
import helper.strategy_helper as st_hp
import helper.visualization as vz_hp
import helper.helper as hp
import helper.file_helper as file_hp
import config.config as config_hp
import helper.twitter_helper as twitter_hp
import helper.pandas_helper as pd_hp

# %% [markdown]
# ### **Plot the activity**

# %%
df = pd.read_csv('./../data/RQ3_replier_info.csv')

# %%
df_pos = df.loc[df['replier_label'] == 1]

df_non_io_activity = df.loc[df['replier_label'] == 0]

# %%
df_non_io_activity.columns
# Out:
# Index(['replier_userid', 'activity_count', 'replier_label', 'following_count',
#        'followers_count', 'age'],
#       dtype='object')

# %%
df_pos.columns
# Out:
# Index(['replier_userid', 'activity_count', 'replier_label', 'following_count',
#        'followers_count', 'age'],
#       dtype='object')

# %% [markdown]
# #### **Viz**

# %%
import helper.visualization as viz_hp

importlib.reload(config_hp)
importlib.reload(viz_hp)

parameters = {
        'data': [df_pos, 
                 df_non_io_activity
                ],
        'figsize': (10, 10),
        'fontsize': 36,
        'tick_size': 28,
        'complementary': True,
        'legend_font': 26,
        'columns': [
            {'column': 'activity_count',
             'label': 'IO replier',
            },{
            'column': 'activity_count',
             'label': 'Normal replier'
            },
        ],
        'xlabel': 'Activity',
        'ylabel': 'CCDF',
        # 'legend_location': 'upper right',
        'log_yscale': False,
        'log_xscale': True,
        'save': {
            'path': './../plots',
            'filename': 'CCDF_tweet_activity_replier.png'
        },
        'random_color': False
}


viz_hp.ccdf(parameters)
# Out:
# ./../plots/CCDF_tweet_activity_replier.png

# %%
print('Activity IO ', df_pos['activity_count'].median())
print('Activity normal ', df_non_io_activity['activity_count'].median())
# Out:
# Activity IO  953.0
# Activity normal  9042.0
